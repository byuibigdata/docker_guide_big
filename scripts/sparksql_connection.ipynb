# %%
import pandas as pd
import numpy as np
import os
from pyspark import SparkConf 
from pyspark.sql import SparkSession # https://spark.apache.org/docs/1.6.1/sql-programming-guide.html
from pyspark.sql import functions as F # access to the sql functions https://spark.apache.org/docs/latest/api/python/pyspark.sql.html#module-pyspark.sql.functions
from IPython.display import HTML

# %%
# To persist our sparksql data from session to session we will use derby.
warehouse_location = os.path.abspath('../../../data/spark-warehouse')
java_options = "-Dderby.system.home=" + warehouse_location
print(warehouse_location)
print(java_options)
# make sure you have set the warehouse location to 'home/jovyan/data/spark-warehouse'
# Out:
# /home/jovyan/data/spark-warehouse
# -Dderby.system.home=/home/jovyan/data/spark-warehouse

# %%
if os.path.normpath("/home/jovyan/data/spark-warehouse") != warehouse_location:
    print('\x1b[6;37;41m' + 'Your path is not correct' + '\x1b[0m')

# %%
# Create the session
conf = (SparkConf()
    .set("spark.ui.port", "4041")
    .set('spark.jars', '/home/jovyan/scratch/postgresql-42.2.18.jar')
    .set("spark.sql.warehouse.dir", warehouse_location) # set above.
    .set("hive.metastore.schema.verification", False)
    .set("javax.jdo.option.ConnectionURL", "jdbc:derby:;databaseName=metastore_db;create=true") # settings to persist data for sparksql
    .set("javax.jdo.option.ConnectionDriverName", "org.apache.derby.jdbc.EmbeddedDriver") # settings to persist data for sparksql
    .set("javax.jdo.option.ConnectionUserName", 'userman') # may not need this
    .set("jdo.option.ConnectionPassword", "pwd") # may not need this
    .set("spark.driver.extraJavaOptions",java_options) # setting where the derby log files are created.
    .set("spark.sql.inMemoryColumnarStorage.compressed", True) # default
    .set("spark.sql.inMemoryColumnarStorage.batchSize",10000) # default
    )

# Create the Session (used to be context)
# you can move the number up or down depending on your memory and processors "local[*]" will use all.
# The conf from above is used in .config.
spark = SparkSession.builder \
    .master("local[3]") \
    .appName('test') \
    .config(conf=conf) \
    .enableHiveSupport() \
    .getOrCreate()

# %%
# spark.stop()
# spark.sql('DROP DATABASE IF EXISTS irs990 CASCADE;')
# spark.sql("create database irs990")
spark.sql("SHOW DATABASES").show()

# %% [markdown]
# ## Pulling data into our Spark environment
#
# In this example, I am using a postgres database as specified in the below properties based on the 990 irs database we are using in CSE 451. If you don't have access to the database, you use the `.csv` file found in `/scratch`.
#
# ### pushing our csv file to a database

# %%
spark.sql('DROP DATABASE IF EXISTS mycsv CASCADE;')
spark.sql("create database mycsv")
spark.sql("USE mycsv")
diamonds = spark.read.format("csv").load("../../../scratch/diamonds.csv")
print(diamonds.limit(5).show(5))
diamonds.write.mode("overwrite").saveAsTable("diamonds")
spark.sql('SHOW TABLES IN mycsv').show()
# Out:
# +-----+-------+-----+-------+-----+-----+-----+----+----+----+
# |  _c0|    _c1|  _c2|    _c3|  _c4|  _c5|  _c6| _c7| _c8| _c9|
# +-----+-------+-----+-------+-----+-----+-----+----+----+----+
# |carat|    cut|color|clarity|depth|table|price|   x|   y|   z|
# | 0.23|  Ideal|    E|    SI2| 61.5|   55|  326|3.95|3.98|2.43|
# | 0.21|Premium|    E|    SI1| 59.8|   61|  326|3.89|3.84|2.31|
# | 0.23|   Good|    E|    VS1| 56.9|   65|  327|4.05|4.07|2.31|
# | 0.29|Premium|    I|    VS2| 62.4|   58|  334| 4.2|4.23|2.63|
# +-----+-------+-----+-------+-----+-----+-----+----+----+----+
#
# None
# +--------+---------+-----------+
# |database|tableName|isTemporary|
# +--------+---------+-----------+
# |   mycsv| diamonds|      false|
# +--------+---------+-----------+

# %% [markdown]
# ### Pulling from our postgress irs990 database into our Spark database
#
# For our CSE 451 students that have access to our database the following sections can be used to see the performance benefits of Spark for large tables.

# %%
properties = {
    'driver': 'org.postgresql.Driver',
    'url': 'jdbc:postgresql://c451_db_1:5432/irs990',
    'user': 'postgres',
    'password': 'postgres1234',
}

# %%
# schema table

schema = spark.read \
    .format('jdbc') \
    .option('driver', properties['driver']) \
    .option('url', properties['url']) \
    .option('dbtable', "information_schema.tables") \
    .option('user', properties['user']) \
    .load()

# %%
tables = schema.toPandas().filter(['table_catalog', 'table_schema', 'table_name']).query('table_schema == "public"')

# %%
HTML(tables.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>table_catalog</th>
#       <th>table_schema</th>
#       <th>table_name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>address_table</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>cmsid_eins</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>django_migrations</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>excess_benefits</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>excess_benefits_types</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>filing_filing</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>fl_loans_from</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>insider_assistance</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>insider_assistance_types</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>insider_transactions</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>insider_transactions_types</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>loans</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>loans_from</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>loans_from_types</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>loans_to</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>loans_to_types</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>metadata_description</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>metadata_group</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>metadata_linenumber</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>metadata_schedulepart</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>metadata_variable</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>not_in_cms</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>org_types</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>part_vi_excerpt</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>pfrb_address_table</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>pfrb_list</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_cntrctrcmpnstn</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_ez_part_0</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_ez_part_i</td>
#     </tr>
#     <tr>
#       <th>41</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_ez_part_ii</td>
#     </tr>
#     <tr>
#       <th>42</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_ez_part_iii</td>
#     </tr>
#     <tr>
#       <th>43</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_ez_part_iv</td>
#     </tr>
#     <tr>
#       <th>44</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_ez_part_v</td>
#     </tr>
#     <tr>
#       <th>45</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_ez_part_vi</td>
#     </tr>
#     <tr>
#       <th>48</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_ezcmpnstnhghstpdempl</td>
#     </tr>
#     <tr>
#       <th>183</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_ezcmpnstnofhghstpdcntrct</td>
#     </tr>
#     <tr>
#       <th>221</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_ezfrgnfnnclaccntcntrycd</td>
#     </tr>
#     <tr>
#       <th>231</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_ezfrgnoffccntrycd</td>
#     </tr>
#     <tr>
#       <th>232</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_ezoffcrdrctrtrstempl</td>
#     </tr>
#     <tr>
#       <th>233</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_ezprgrmsrvcaccmplshmnt</td>
#     </tr>
#     <tr>
#       <th>234</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_ezspclcndtndsc</td>
#     </tr>
#     <tr>
#       <th>235</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_ezsttswhrcpyofrtrnisfldcd</td>
#     </tr>
#     <tr>
#       <th>236</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_frgncntrycd</td>
#     </tr>
#     <tr>
#       <th>237</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_frm990prtviisctna</td>
#     </tr>
#     <tr>
#       <th>238</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_othrexpnss</td>
#     </tr>
#     <tr>
#       <th>239</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_othrrvnmsc</td>
#     </tr>
#     <tr>
#       <th>240</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_part_0</td>
#     </tr>
#     <tr>
#       <th>241</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_part_i</td>
#     </tr>
#     <tr>
#       <th>242</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_part_iii</td>
#     </tr>
#     <tr>
#       <th>243</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_part_iv</td>
#     </tr>
#     <tr>
#       <th>244</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_part_ix</td>
#     </tr>
#     <tr>
#       <th>245</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_part_v</td>
#     </tr>
#     <tr>
#       <th>246</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_part_vi</td>
#     </tr>
#     <tr>
#       <th>247</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_part_vii</td>
#     </tr>
#     <tr>
#       <th>248</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_part_viii</td>
#     </tr>
#     <tr>
#       <th>249</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_part_x</td>
#     </tr>
#     <tr>
#       <th>250</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_part_xi</td>
#     </tr>
#     <tr>
#       <th>251</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_part_xii</td>
#     </tr>
#     <tr>
#       <th>252</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_pf_part_0</td>
#     </tr>
#     <tr>
#       <th>253</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_pf_part_i</td>
#     </tr>
#     <tr>
#       <th>254</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_pf_part_ii</td>
#     </tr>
#     <tr>
#       <th>255</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_pf_part_iii</td>
#     </tr>
#     <tr>
#       <th>256</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_pf_part_iv</td>
#     </tr>
#     <tr>
#       <th>257</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_pf_part_ixa</td>
#     </tr>
#     <tr>
#       <th>258</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_pf_part_ixb</td>
#     </tr>
#     <tr>
#       <th>259</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_pf_part_v</td>
#     </tr>
#     <tr>
#       <th>260</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_pf_part_vi</td>
#     </tr>
#     <tr>
#       <th>261</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_pf_part_viia</td>
#     </t

# %%
# import shutil
# shutil.rmtree('/home/jovyan/data/spark-warehouse/metastore_db')
# shutil.rmtree('/home/jovyan/data/spark-warehouse')
# shutil.rmtree('/home/jovyan/data/spark-warehouse/irs990.db/address_table')
# shutil.rmtree('/home/jovyan/data/spark-warehouse/irs990.db/return_EZOffcrDrctrTrstEmpl')
# shutil.rmtree('/home/jovyan/data/spark-warehouse/irs990.db/tmp_990ez_employees')

# spark.sql('DROP TABLE IF EXISTS return_EZOffcrDrctrTrstEmpl')
# spark.sql('DROP TABLE IF EXISTS address_table')
# spark.sql('DROP TABLE IF EXISTS tmp_990ez_employees')

# %%
return_EZOffcrDrctrTrstEmpl = spark.read \
    .format('jdbc') \
    .option('driver', properties['driver']) \
    .option('url', properties['url']) \
    .option('dbtable', "return_EZOffcrDrctrTrstEmpl") \
    .option('user', properties['user']) \
    .load()

# %%
address = spark.read \
    .format('jdbc') \
    .option('driver', properties['driver']) \
    .option('url', properties['url']) \
    .option('dbtable', 'address_table') \
    .option('user', properties['user']) \
    .load()

# %%
print(address.count())
print(return_EZOffcrDrctrTrstEmpl.count())
# Out:
# 2243560
# 4698799

# %%
print('Number of partitions: {}'.format(address.rdd.getNumPartitions()))
print('Number of partitions: {}'.format(return_EZOffcrDrctrTrstEmpl.rdd.getNumPartitions()))
# Out:
# Number of partitions: 1
# Number of partitions: 1

# %%
address = address.repartition(50)

# %%
return_EZOffcrDrctrTrstEmpl = return_EZOffcrDrctrTrstEmpl.repartition(50)

# %%
print('Number of partitions: {}'.format(address.rdd.getNumPartitions()))
print('Number of partitions: {}'.format(return_EZOffcrDrctrTrstEmpl.rdd.getNumPartitions()))
# Out:
# Number of partitions: 50
# Number of partitions: 50

# %%
spark.sql("USE irs990")
address.write.saveAsTable("address_table")
return_EZOffcrDrctrTrstEmpl.write.saveAsTable('return_EZOffcrDrctrTrstEmpl')

# %%
spark.sql('SHOW TABLES IN irs990').show()
# Out:
# +--------+--------------------+-----------+
# |database|           tableName|isTemporary|
# +--------+--------------------+-----------+
# |  irs990|       address_table|      false|
# |  irs990|return_ezoffcrdrc...|      false|
# |  irs990| tmp_990ez_employees|      false|
# +--------+--------------------+-----------+

# %%
# %%time
sql_query_join = """
SELECT addt.*, rez.PrsnNm, rez.TtlTxt, rez.CmpnstnAmt
FROM return_EZOffcrDrctrTrstEmpl as rez
    LEFT JOIN address_table as addt
    ON rez.ein = addt.ein
    AND rez.object_id = addt.object_id
    ORDER BY addt.ein DESC, addt.object_id DESC;
"""

tmp_990ez_employees = spark.sql(sql_query_join)

tmp_990ez_employees.write.saveAsTable('tmp_990ez_employees')
# Out:
# CPU times: user 8.82 ms, sys: 5.94 ms, total: 14.8 ms
# Wall time: 49 s

# %%
# https://github.com/jsfenfen/990-xml-database/blob/master/directors.sh

# DROP TABLE IF EXISTS tmp_990ez_employees;
# SELECT address_table.*,
# 	'/IRS990EZ' as form,
#    "PrsnNm",
#    "TtlTxt",
#    "CmpnstnAmt" 
#    INTO temporary table tmp_990EZ_employees
#    FROM return_EZOffcrDrctrTrstEmpl
# 	LEFT JOIN address_table ON return_EZOffcrDrctrTrstEmpl.ein = address_table.ein
# 	AND return_EZOffcrDrctrTrstEmpl.object_id= address_table.object_id;

# %%
temp = spark.sql('select * from tmp_990ez_employees')
temp.limit(20).toPandas()
# Out:
#           ein           object_id RtrnHdr_TxPrdEndDt  RtrnHdr_TxYr  \
# 0   010674021  201411229349200611         2013-12-31          2013
# 1   010674021  201411229349200611         2013-12-31          2013
# 2   010674021  201411229349200611         2013-12-31          2013
# 3   010674021  201411229349200611         2013-12-31          2013
# 4   010674021  201411229349200611         2013-12-31          2013
# 5   010674021  201411229349200611         2013-12-31          2013
# 6   010674021  201411229349200611         2013-12-31          2013
# 7   010674021  201411229349200611         2013-12-31          2013
# 8   010674021  201411229349200611         2013-12-31          2013
# 9   010674021  201411229349200611         2013-12-31          2013
# 10  010674021  201411229349200611         2013-12-31          2013
# 11  010673858  201922039349200772         2019-03-31          2018
# 12  010673858  201922039349200772         2019-03-31          2018
# 13  010673858  201922039349200772         2019-03-31          2018
# 14  010673858  201922039349200772         2019-03-31          2018
# 15  010673858  201922039349200772         2019-03-31          2018
# 16  010673858  201922039349200772         2019-03-31          2018
# 17  010673858  201922039349200772         2019-03-31          2018
# 18  010673858  201922039349200772         2019-03-31          2018
# 19  010673858  201922039349200772         2019-03-31          2018
#
#                     BsnssNm_BsnssNmLn1Txt BsnssNm_BsnssNmLn2Txt  \
# 0   Clinton Community Faculty Association                  None
# 1   Clinton Community Faculty Association                  None
# 2   Clinton Community Faculty Association                  None
# 3   Clinton Community Faculty Association                  None
# 4   Clinton Community Faculty Association                  None
# 5   Clinton Community Faculty Association                  None
# 6   Clinton Community Faculty Association                  None
# 7   Clinton Community Faculty Association                  None
# 8   Clinton Community Faculty Association                  None
# 9   Clinton Community Faculty Association                  None
# 10  Clinton Community Faculty Association                  None
# 11               SONS OF ITALY IN AMERICA                  None
# 12               SONS OF ITALY IN AMERICA                  None
# 13               SONS OF ITALY IN AMERICA                  None
# 14               SONS OF ITALY IN AMERICA                  None
# 15               SONS OF ITALY IN AMERICA                  None
# 16               SONS OF ITALY IN AMERICA                  None
# 17               SONS OF ITALY IN AMERICA                  None
# 18               SONS OF ITALY IN AMERICA                  None
# 19               SONS OF ITALY IN AMERICA                  None
#
#    BsnssOffcr_PrsnNm BsnssOffcr_PrsnTtlTxt BsnssOffcr_PhnNm  \
# 0         Chris Ford             President             None
# 1         Chris Ford             President             None
# 2         Chris Ford             President             None
# 3         Chris Ford             President             None
# 4         Chris Ford             President             None
# 5         Chris Ford             President             None
# 6         Chris Ford             President             None
# 7         Chris Ford             President             None
# 8         Chris Ford             President             None
# 9         Chris Ford             President             None
# 10        Chris Ford             President             None
# 11       ANGELA RAPP             TREASURER       5185372373
# 12       ANGELA RAPP             TREASURER       5185372373
# 13       ANGELA RAPP             TREASURER       5185372373
# 14       ANGELA RAPP             TREASURER       5185372373
# 15       ANGELA RAPP             TREASURER       5185372373
# 16       ANGELA RAPP             TREASURER       5185372373
# 17       ANGELA RAPP             TREASURER       5185372373
# 18       ANGELA RAPP             TREASURER       5185372373
# 19       ANGELA RAPP             TREASURER       5185372373
#
#    BsnssOffcr_EmlAddrssTxt  ... USAddrss_SttAbbrvtnCd USAddrss_ZIPCd  \
# 0                     None  ...                    NY          12901
# 1                     None  ...                    NY          12901
# 2                     None  ...                    NY          12901
# 3                     None  ...                    NY          12901
# 4                     None  ...                    NY          12901
# 5                     None  ...                    NY          12901
# 6                     None  ...                    NY          12901
# 7                     None  ...                    NY          12901
# 8                     None  ...                    NY          12901
# 9                     None  ...                    NY          12901
# 10                    None  ...                    NY          12901
# 11                    None  ...                    NY      125340949
# 12                    None  ...                    NY      125340949
# 13                    None  ...                    NY      125340949
# 14                    None  ...                    NY      125340949
# 15                    None  ...                    NY      125340949
# 16                    None  ...                    NY      125340949
# 17                    None  ...                    NY      125340949
# 18                    None  ...                    NY      125340949
# 19                    None  ...                    NY      125340949
#
#    FrgnAddrss_AddrssLn1Txt FrgnAddrss_AddrssLn2Txt FrgnAddrss_CtyNm  \
# 0                     None                    None             None
# 1                     None                    None             None
# 2                     None                    None             None
# 3                     None                    None             None
# 4                     None                    None             None
# 5                     None                    None             None
# 6                     None                    None             None
# 7                     None                    None             None
# 8                     None                    None             None
# 9                     None                    None             None
# 10                    None                    None             None
# 11                    None                    None             None
# 12                    None                    None             None
# 13                    None                    None             None
# 14                    None                    None             None
# 15                    None                    None             None
# 16                    None                    None             None
# 17                    None                    None             None
# 18                    None                    None             None
# 19                    None                    None             None
#
#    FrgnAddrss_PrvncOrSttNm FrgnAddrss_CntryCd                  PrsnNm  \
# 0                     None               None      Catherine Eloranto
# 1                     None               None            Darcy Purick
# 2                     None               None              June Foley
# 3                     None               None              Chris Ford
# 4                     None               None          Angela Barnaby
# 5                     None               None         Michael Lawliss
# 6                     None               None             Donna Lynch
# 7                     None               None          Willow Nolland
# 8                     None               None             Lynn Fowler
# 9                     None               None            Patti LaDuke
# 10                    None               None              Jeff Myers
# 11                    None               None       MARIA HENDRICKSON
# 12                    None               None  PHILOMENIA VAN DE CARR
# 13                    None               None           JOANNE CONCRA
# 14                    None               None                ED KONOW
# 15                    None               None             ANGELA RAPP
# 16                    None               None            GUY APICELLA
# 17                    None               None             ROBERT FONK
# 18                    None               None         THOMAS DEPIETRO
# 19                    None               None            ARTHUR FRANK
#
#                       TtlTxt CmpnstnAmt
# 0                  President       2433
# 1             Representative        350
# 2             Representative        986
# 3                  President       2433
# 4             Representative          0
# 5             Representative        175
# 6             representative        175
# 7             representative        175
# 8             Vice President        811
# 9                  Treasurer       1622
# 10                 Secretary       1622
# 11                   TRUSTEE          0
# 12                     GUARD          0
# 13                  CHAPLAIN          0
# 14                   TRUSTEE          0
# 15                 TREASURER          0
# 16                 PRESIDENT          0
# 17                   TRUSTEE          0
# 18                   TRUSTEE          0
# 19  IMMEDIATE PAST PRESIDENT          0
#
# [20 rows x 24 columns]
